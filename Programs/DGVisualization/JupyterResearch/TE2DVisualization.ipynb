# %% [markdown]
# # Программа визуализации расчетов 2D Уравнения Переноса

# %%
from TE2DTests import *

# %%
print(CalculationResultsPath)
print(TECalculationsPath)
print(TE2DCalcRes)

print(PlotOutputPath)
print(TEPlotPath)
print(TE2DPlotRes)
# Out:
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/CalculationResults
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/CalculationResults/TransportEquation
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/CalculationResults/TransportEquation/Solver2D
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/GraphicsResults
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/GraphicsResults/TransportEquation
# /mnt/UbuntuSpace/Projects/DigitalGeometry/Programs/Output/GraphicsResults/TransportEquation/Solver2D

# %% [markdown]
# ## Solve2DRectMovementTest

# %%
TE2DTestVisualization(TE2DCalcRes, TE2DPlotRes, "Solve2DRectMovementTest", "area_128x128_t_400.txt", 10, 3, False)
# Out:
# cellCountX:  128
# cellCountY:  128
# dx:  0.0078125
# NTimeSteps:  400
# realNTimeSteps:  50
# dt:  0.015625
# MovieWriter PillowWriter unavailable; using Pillow instead.
# Animation real time:  6.25
# Animation real time step:  0.375
# Animation fps:  2.6666666666666665

# %% [markdown]
# ## Solve2DWhiteBearMovementTest

# %%
TE2DTestVisualization(TE2DCalcRes, TE2DPlotRes, "Solve2DWhiteBearMovementTest", "area_128x128_t_400.txt", 10, 3, False)
# Out:
# cellCountX:  128
# cellCountY:  128
# dx:  0.0078125
# NTimeSteps:  400
# realNTimeSteps:  50
# dt:  0.015625
# MovieWriter PillowWriter unavailable; using Pillow instead.
# Animation real time:  6.25
# Animation real time step:  0.375
# Animation fps:  2.6666666666666665

# %%
TE2DTestVisualization(DG2DCalcRes, DG2DPlotRes, "PlusRotateTest", "TE_area_128_t_1024.txt", 10, 3, False)
# Out:
# cellCountX:  128
# cellCountY:  128
# dx:  0.015625
# NTimeSteps:  1024
# realNTimeSteps:  50
# dt:  0.000976562
# MovieWriter PillowWriter unavailable; using Pillow instead.
# Animation real time:  0.999999488
# Animation real time step:  0.059999969279999996
# Animation fps:  16.66667520000437
